# %% [markdown]
# # Module 5 Final Project
#
# Student name: **Cynthia Pedrasa**
# Student pace: **self paced**
# Scheduled project review date/time:  **Tue, Mar 26, 2019 3:30pm - 4:15pm (EDT)**
# Instructor name: **Jeff Herman**
# Blog post URL:  https://cpedrasa.github.io/exploratory_data_analysis
#
# ## Table of contents
#
# Data Science Framework
#
# **Part I** Obtain Data, Scrub Data, Data Exploration
#
# **Part II**
#
# Evaluate Algorithms - Train Test Split ; Test Options ; Eval metrics
# Improve with algorithm tuning- ml alg parameters grid search, random search
# Improve performance with ensemble, bagging, boosting
#
# IV.   Evaluate Algorithms
#   + A. <a href="#4a.-Train-Test-Split">Train Test Split</a>
#   + B. <a href="#4b.-Cross-Validation">Cross Validation</a>
#   + C. <a href="#4c.-Evaluation-Metric">Evaluation Metric</a>
#
# V.    Machine Learning Algorithms/Tuning/Improve Accuracy
#   +    <a href="#Logistic-Regression">Logistic Regression</a>
#   +    <a href="#KNeighborsClassifier">KNeighborsClassifier</a>
#   +    <a href="#DecisionTreeClassifier">DecisionTreeClassifier</a>
#
# VI.   Ensembles
#   +    <a href="#RandomForestClassifier">RandomForestClassifier</a>
#   +    <a href="#BaggingClassifier">BaggingClassifier</a>
#   +    <a href="#BalancedBaggingClassifier">BalancedBaggingClassifier</a>
#   +    <a href="#ADABoostClassifier">ADABoostClassifier</a>
#   +    <a href="#GradientBoostingClassifier">Gradient Boosting Classifier</a>
#   +    <a href="#XGBoostClassifier">XGBoostClassifier</a>
#   +    <a href="#SVM-Classifier">SVM Classifier</a>
#   +    <a href="#Finalize-Save-Model-for-Later-Use">Finalize Save Model for Later Use</a>
#   +    <a href="#Predictions">Predictions</a>
#
#
# VII.   <a href="#iNterpreting-the-Data">iNterpreting the Data</a>
#
# VIII.  <a href="#Future-Work">Future Work</a>

# %%
import pandas as pd
from pandas import set_option
import pickle
import time
import numpy as np
from numpy import mean
from numpy import std
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt # plotting library for Python
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")

import pyodbc
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

import warnings
warnings.filterwarnings('ignore')
import scipy as sp

from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold, cross_val_score,  GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_predict 
from sklearn.utils.class_weight import compute_class_weight
from sklearn.datasets import make_classification
from collections import Counter

from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.ensemble import BalancedBaggingClassifier 
from imblearn.ensemble import BalancedRandomForestClassifier

from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score, roc_curve, auc
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
# Out:
# Using TensorFlow backend.

# %%
# with open('readmissions.pickle', "rb") as f:
#     df = pickle.load(f)

# load data set 
import pandas as pd
df = pd.read_csv('final_data.csv')
y = df.readmitted
X = df.drop(['readmitted'], axis = 1)

# split into train/test sets 
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=2)
train_0, train_1 = len(y_train[y_train==0]), len(y_train[y_train==1])
test_0, test_1 = len(y_test[y_test==0]), len(y_test[y_test==1])
print('Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))

# split into train/test sets with same class ratio 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=2, stratify=y)
train_0, train_1 = len(y_train[y_train==0]), len(y_train[y_train==1])
test_0, test_1 = len(y_test[y_test==0]), len(y_test[y_test==1])
print('Stratified Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))
# Out:
# Train: 0=27672, 1=2595, Test: 0=27705, 1=2563
# Stratified Train: 0=27688, 1=2579, Test: 0=27689, 1=2579

# %%
#Create functions to load data, split traind & test data and time execution


def load_data(file_name):   
    import pandas as pd
    df = pd.read_csv(file_name)
    y = df.readmitted
    X = df.drop(['readmitted'], axis = 1)
    return X, y

def train_test_dist(X, y):
    train_0, train_1 = len(y_train[y_train==0]), len(y_train[y_train==1])
    test_0, test_1 = len(y_test[y_test==0]), len(y_test[y_test==1])
    print('Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))
    
def split_train_test(X, y):
    X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=2, stratify = y )
    return X_train, X_test, y_train, y_test 

start = time.time()
def exec_time():
    execution_time = time.time() - start
    print('Execution time', time.strftime("%H:%M:%S", time.gmtime(execution_time)))

exec_time()
# Out:
# Execution time 00:00:00

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## 3e.  Feature Selection

# %%
# def plot_feature_importances(model):
#     feature_names = X.columns
#     feature_imports = model.feature_importances_
#     most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(20, "Importance")
#     most_imp_features.sort_values(by="Importance", inplace=True)
#     plt.figure(figsize=(10,10))
#     plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
#     plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
#     plt.xlabel('Importance')
#     plt.title('Most important features ')
#     plt.show()

# %%
# # Feature Importance with Extra Trees Classifier
# start = time.time()
# # feature extraction
# ET = ExtraTreesClassifier()
# ET.fit(X, y)

# plot_feature_importances(ET)
# execution_time = time.time() - start
# print('Execution time', time.strftime("%H:%M:%S", time.gmtime(execution_time)))

# %%
# df = datafinal.copy(deep=True)
# selected_features = ['num_lab_procedures',
#  'num_medications',
#  'time_in_hospital',
#  'age',
#  'num_procedures',
#  'number_diagnoses',
#  'number_meds',
#  'gender_1',
#  'race_Caucasian',
#  'num_encounters_log',
#  'admission_source_id_7',
#  'A1Cresult_2',
#  'admission_type_id_3',
#  'ICDCat1_1',
#  'discharge_disposition_id_2',
#  'change_1',
#  'A1Cresult_1',
#  'number_changes',   
#  'ICDCat1_3',
#  'admission_type_id_5']
 
# X = df[selected_features]
# y = df['readmitted']

# #define X and y 
# X = df.drop(['readmitted'], axis = 1)
# y = df.readmitted

# test_size = 0.5

# seed = 2

# X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=2, stratify=y)

# #Stratified Kfold
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# print('Dataset: Class 0=%d, Class 1=%d' % (len(y[y==0]), len(y[y==1])))
# print('Train: Class 0=%d, Class 1=%d' % (len(y_train[y_train==0]), len(y_train[y_train==1]))) 
# print('Test: Class 0=%d, Class 1=%d' % (len(y_test[y_test==0]), len(y_test[y_test==1])))

# print('Relative frequencies of the class (train)')
# print(y_train.value_counts(normalize=True))
# print('Relative frequencies of the class (test)')
# print(y_test.value_counts(normalize=True))

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # Evaluate Algorithms

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %%
#Calculate prevalence
def calc_prevalence(y_test):
    return (sum(y_test)/len(y_test))
#Calculate specificity
def calc_specificity(y_test, predictions, thresh):
    # calculates specificity
    return sum((predictions < thresh) & (y_test == 0)) /sum(y_test ==0)

#Calculate and print scores        
def print_scores(y_test, y_pred):
    from sklearn.metrics import accuracy_score 
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import mean_squared_error  
    from sklearn.metrics import r2_score
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import auc
    from sklearn.metrics import classification_report
    from sklearn.metrics import roc_curve
    from sklearn.metrics import precision_score       
    print("Accuracy: {}".format((accuracy_score(y_test, y_pred).round(decimals=4)*100)),'%')
    print("Precision: {}".format(precision_score(y_test, y_pred)))
    print("Recall: {}".format(recall_score(y_test, y_pred)))
    print("F1-score: {}".format(f1_score(y_test, y_pred)))
    print("R2: {}".format(r2_score(y_test, y_pred)))
    print("MSE: {}".format(mean_squared_error(y_test, y_pred)))
    print("Prevalence: {}".format(calc_prevalence(y_pred)))
    print("Specificity: {}".format(calc_specificity(y_test, y_pred, 0.5)))
    print('---------------------------------------------------------------------')
    print('\n','Classification Report:')
    print(classification_report(y_test, y_pred, target_names = ['NO', 'YES']))
    print('---------------------------------------------------------------------')
    # Confusion matrix plot   
    from sklearn.metrics import confusion_matrix
    conf_mat = confusion_matrix(y_true=y_test, y_pred=y_pred)
    print('Confusion matrix:\n', conf_mat)
    labels = ['Class 0', 'Class 1']
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(conf_mat, cmap=plt.cm.Blues)
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('Expected')
    plt.show()

#plot ROC curve
def plot_roc_curve(y_test, model_probs, lblname):
    from sklearn.metrics import precision_recall_curve
    from sklearn.metrics import auc
    from sklearn.metrics import f1_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import precision_score
    auc = roc_auc_score(y_test, model_probs) 
    fpr, tpr, _ = roc_curve(y_test, model_probs)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    plt.plot(fpr, tpr, color='darkorange',
             lw=2, label = 'ROC AUC: %.3f' % roc_auc_score(y_test, model_probs).round(decimals=3))
    plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--', alpha=.8)
    plt.xlim([0,1])
    plt.ylim([0,1])
    plt.xticks(np.arange(0,1.1,0.1))
    plt.yticks(np.arange(0,1.1,0.1))
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic (ROC) Curve')
    plt.legend(loc="lower right")
    plt.show();
    
# plot the Precision-Recall Curve
def plot_pr_curve(y_test, y_pred, model_probs, lblname):
    from sklearn.metrics import precision_recall_curve
    from sklearn.metrics import auc
    from sklearn.metrics import f1_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import precision_score
    precision, recall, _ = precision_recall_curve(y_test, model_probs)
    f1, pr_auc = f1_score(y_test, y_pred), auc(recall, precision)
    print('f1=%.3f PR AUC=%.3f' % (f1, pr_auc))
    # calculate the no skill line as the proportion of the positive class
    no_skill = len(y[y==1]) / len(y)
    # plot the no skill precision-recall curve
    plt.plot([0, 1], [no_skill, no_skill],color='red', linestyle='--', label='Random') 
    precision, recall, _ = precision_recall_curve(y_test, model_probs)
    plt.plot(recall, precision, marker='.', label=  'PR AUC: %.3f' % auc(recall, precision).round(decimals=3))
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall curve')
      # show the legend
    plt.legend()
      # show the plot
    plt.show()
    

#Calculate scores at 25% threshold
def print_scores_thresh(y_test, y_pred):
    print('---------------------------------------------------------------------')
    print('scores with threshold = 0.25')
    print('Accuracy: %.3f'%(accuracy_score(y_test, (LR_probs >= 0.25).astype('int'))))
    print('Recall: %.3f'%(recall_score(y_test, (LR_probs >= 0.25).astype('int'))))
    print('Precision: %.3f'%(precision_score(y_test, (LR_probs >= 0.25).astype('int'))))
    print('F1-score: %.3f'%(f1_score(y_test, (LR_probs >= 0.25).astype('int'))))
    print('AUC: %.3f'%(roc_auc_score(y_test, (LR_probs >= 0.25).astype('int'))))
    print("Prevalence: {}".format(calc_prevalence(LR_probs >= 0.25).astype('int')))
    print("Specificity: {}".format(calc_specificity(y_test, y_pred, 0.25)))
    print('---------------------------------------------------------------------')
    print(classification_report(y_test, (LR_probs >= 0.25).astype('int'), target_names = ['NO', 'YES']))
    display(pd.crosstab(y_test, y_pred, rownames=['True'], colnames=['Predicted'], margins=True))
    print('')

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %%
#from imblearn.over_sampling import SMOTE
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

sm = SMOTE(random_state=2, ratio=1.0)                                 # Define sampling
X_train, y_train = sm.fit_sample(X_train, y_train)

# define model
model = LogisticRegression(solver='lbfgs').fit(X_train, y_train)      # define/fit model

LR_probs= model.predict_proba(X_test)[:, 1]   # predict probabilities for the positive outcome only
y_pred = model.predict(X_test)                # predict


#Summary Report:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, LR_probs,  'LR')
plot_pr_curve(y_test, y_pred, LR_probs, 'LR')   
    
exec_time()
# Out:
# Accuracy: 65.18 %
# Precision: 0.12261735419630157
# Recall: 0.5013571151609151
# F1-score: 0.19704358427308746
# R2: -3.466664223495748
# MSE: 0.348156468878023
# Prevalence: 0.3483877362230739
# Specificity: 0.6658600888439452
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.93      0.67      0.78     27689
#          YES       0.12      0.50      0.20      2579
#
#     accuracy                           0.65     30268
#    macro avg       0.53      0.58      0.49     30268
# weighted avg       0.87      0.65      0.73     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[18437  9252]
#  [ 1286  1293]]
# f1=0.197 PR AUC=0.128
# Execution time 00:00:01

# %% [markdown]
# # Logistic Regression

# %%
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

model = LogisticRegression(solver='lbfgs').fit(X_train, y_train)      # define/fit model

LR_probs= model.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = model.predict(X_test)                           # predict

fpr_LR, tpr_LR, thresholds = roc_curve(y_test, LR_probs)              #calculate roc_auc score
LR_precision, LR_recall, _ = precision_recall_curve(y_test, LR_probs) #calculate pr_auc score

#Summary report:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, LR_probs,  'LR')
plot_pr_curve(y_test, y_pred, LR_probs, 'LR')   
    
exec_time()
# Out:
# Accuracy: 91.47999999999999 %
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# R2: -0.09314168081187457
# MSE: 0.08520549755517379
# Prevalence: 0.0
# Specificity: 1.0
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.00      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.46      0.50      0.48     30268
# weighted avg       0.84      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27689     0]
#  [ 2579     0]]
# f1=0.000 PR AUC=0.127
# Execution time 00:00:01

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Logistic Regression Model Tuning

# %%
## ⏰ This cell may take a long time to run!
# grid search class weights with logistic regression for imbalance classification
start = time.time()

# split into train/test sets with same class ratio
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=2, stratify=y)

# define model
lr = LogisticRegression(solver='lbfgs')

# define grid
C_param_range = [0.001, 0.01, 0.1, 1, 10, 100]
balance = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}] 

param_grid = dict(class_weight=balance, C=C_param_range)

# evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# define grid search
grid = GridSearchCV(estimator=lr, param_grid=param_grid, cv=cv, n_jobs=-1, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
               
# print results
print("Best AUC score: %f using  %s" % (grid_result.best_score_, grid_result.best_params_))

# report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('%f (%f) with: %r' % (mean, stdev, param))
    
execution_time = time.time() - start
print('Execution time', time.strftime("%H:%M:%S", time.gmtime(execution_time)))

"""
RESULT:
Best AUC score: 0.616404 using  {'C': 0.001, 'class_weight': {0: 1, 1: 10}}
Execution time 00:02:47
"""
# Out:
# Best AUC score: 0.616489 using  {'C': 0.001, 'class_weight': {0: 1, 1: 10}}
# 0.593802 (0.021240) with: {'C': 0.001, 'class_weight': {0: 100, 1: 1}}
# 0.600583 (0.018166) with: {'C': 0.001, 'class_weight': {0: 10, 1: 1}}
# 0.599919 (0.018418) with: {'C': 0.001, 'class_weight': {0: 1, 1: 1}}
# 0.616489 (0.018008) with: {'C': 0.001, 'class_weight': {0: 1, 1: 10}}
# 0.613639 (0.016228) with: {'C': 0.001, 'class_weight': {0: 1, 1: 100}}
# 0.566539 (0.021706) with: {'C': 0.01, 'class_weight': {0: 100, 1: 1}}
# 0.581558 (0.019932) with: {'C': 0.01, 'class_weight': {0: 10, 1: 1}}
# 0.596163 (0.023795) with: {'C': 0.01, 'class_weight': {0: 1, 1: 1}}
# 0.616414 (0.015368) with: {'C': 0.01, 'class_weight': {0: 1, 1: 10}}
# 0.615538 (0.015473) with: {'C': 0.01, 'class_weight': {0: 1, 1: 100}}
# 0.572634 (0.021662) with: {'C': 0.1, 'class_weight': {0: 100, 1: 1}}
# 0.585558 (0.018448) with: {'C': 0.1, 'class_weight': {0: 10, 1: 1}}
# 0.594190 (0.019202) with: {'C': 0.1, 'class_weight': {0: 1, 1: 1}}
# 0.615213 (0.014228) with: {'C': 0.1, 'class_weight': {0: 1, 1: 10}}
# 0.615171 (0.014901) with: {'C': 0.1, 'class_weight': {0: 1, 1: 100}}
# 0.568652 (0.022275) with: {'C': 1, 'class_weight': {0: 100, 1: 1}}
# 0.581554 (0.022788) with: {'C': 1, 'class_weight': {0: 10, 1: 1}}
# 0.589526 (0.021583) with: {'C': 1, 'class_weight': {0: 1, 1: 1}}
# 0.615339 (0.014816) with: {'C': 1, 'class_weight': {0: 1, 1: 10}}
# 0.615524 (0.016074) with: {'C': 1, 'class_weight': {0: 1, 1: 100}}
# 0.568245 (0.021785) with: {'C': 10, 'class_weight': {0: 100, 1: 1}}
# 0.583386 (0.022024) with: {'C': 10, 'class_weight': {0: 10, 1: 1}}
# 0.596313 (0.017888) with: {'C': 10, 'class_weight': {0: 1, 1: 1}}
# 0.615295 (0.016101) with: {'C': 10, 'class_weight': {0: 1, 1: 10}}
# 0.614912 (0.016428) with: {'C': 10, 'class_weight': {0: 1, 1: 100}}
# 0.568852 (0.022384) with: {'C': 100, 'class_weight': {0: 100, 1: 1}}
# 0.581990 (0.020221) with: {'C': 100, 'class_weight': {0: 10, 1: 1}}
# 0.592895 (0.018317) with: {'C': 100, 'class_weight': {0: 1, 1: 1}}
# 0.615791 (0.014728) with: {'C': 100, 'class_weight': {0: 1, 1: 10}}
# 0.615364 (0.015053) with: {'C': 100, 'class_weight': {0: 1, 1: 100}}
# Execution time 00:01:58
# "\nRESULT:\nBest AUC score: 0.616404 using  {'C': 0.001, 'class_weight': {0: 1, 1: 10}}\nExecution time 00:02:47\n"

# %%
#Let's run the model again with the hypertuned parameters and scaled data
start = time.time()

X, y = load_data('final_data.csv')                                    # load data

X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data


# sm = SMOTE(random_state=2, ratio=1.0)                               # Define Oversampling
# X_train, y_train = sm.fit_sample(X_train, y_train)                  # fit on SMOTE on train data


LR_tuned = Pipeline(steps=[('t', StandardScaler())                        # Model w/ Tuned params
                           ,('m',LogisticRegression(C=0.001
                           , class_weight={0: 1, 1: 10}
                           , solver='lbfgs'))]).fit(X_train, y_train)     #fit the model

LRt_probs= LR_tuned.predict_proba(X_test)[:,1]                # predict probabilities for the positive outcome only

y_pred = LR_tuned.predict(X_test) # predict 
fpr_LRt, tpr_LRt, thresholds = roc_curve(y_test, LRt_probs)               #calculate roc_auc score
LRt_precision, LRt_recall, _ = precision_recall_curve(y_test, LRt_probs)  #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, LRt_probs,  'LR')
plot_pr_curve(y_test, y_pred, LRt_probs, 'LR')   
 
exec_time()
# Out:
# Accuracy: 69.28 %
# Precision: 0.13160780872998465
# Recall: 0.46529662659945714
# F1-score: 0.205180815593742
# R2: -2.940650719855757
# MSE: 0.3071560724197172
# Prevalence: 0.30124223602484473
# Specificity: 0.7140380656578424
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.93      0.71      0.81     27689
#          YES       0.13      0.47      0.21      2579
#
#     accuracy                           0.69     30268
#    macro avg       0.53      0.59      0.51     30268
# weighted avg       0.87      0.69      0.76     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[19771  7918]
#  [ 1379  1200]]
# f1=0.205 PR AUC=0.133
# Execution time 00:00:00

# %% [markdown]
# **Tuning result:**  As seen from the above, the ROC AUC score improved from ROC AUC 0.623 to ROC AUC 0.626 with the hypertuned parameters.
# However, the score is not good enough so let's evaluate other models.
# OLLogistic ROC AUC 0.623
# Logistic PR AUC: 0.132
# Logistic ROC AUC 0.626
# Logistic PR AUC: 0.130

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # KNeighborsClassifier

# %%
start = time.time()

X, y = load_data('final_data.csv')                                            # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)                    # split data

KNN = Pipeline(steps=[('t', StandardScaler())
                      ,('m', KNeighborsClassifier ())]).fit(X_train, y_train) # define/fit model

KNN_probs = KNN.predict_proba(X_test)[:, 1]             # predict probabilities for the positive 
y_pred = KNN.predict(X_test)                                                  # predict 

fpr_KNN, tpr_KNN, thresholds = roc_curve(y_test, KNN_probs)                   #calculate roc_auc score
KNN_precision, KNN_recall, _ = precision_recall_curve(y_test, KNN_probs)      #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, KNN_probs,  'KNN')
plot_pr_curve(y_test, y_pred, KNN_probs, 'KNN') 

exec_time()
# Out:
# Accuracy: 90.97 %
# Precision: 0.1461187214611872
# Recall: 0.01240791004265219
# F1-score: 0.0228734810578985
# R2: -0.15884038594015704
# MSE: 0.09032641733844324
# Prevalence: 0.007235364080877494
# Specificity: 0.9932464155440789
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.92      0.99      0.95     27689
#          YES       0.15      0.01      0.02      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.53      0.50      0.49     30268
# weighted avg       0.85      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27502   187]
#  [ 2547    32]]
# f1=0.023 PR AUC=0.102
# Execution time 00:01:19

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # KNN Tuning Parameters

# %%
## ⏰ This cell may take about a minute to run!

start = time.time()
#Improve model performance - find the optimal number of neighbors to use for the classifier. 
#To do this, complete the find_best_k() function below to iterate over multiple values of K and 
#find the value of K that returns the best overall performance
def find_best_k(X_train, y_train, X_test, y_test, min_k=1, max_k=25):
    best_k = 0
    best_score = 0.0
    for k in range(min_k, max_k+1, 2):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        preds = knn.predict(X_test)
        f1 = f1_score(y_test, preds)
        if f1 > best_score:
            best_k = k
            best_score = f1
    
    print("Best Value for k: {}".format(best_k))
    print("F1-Score: {}".format(best_score))
find_best_k(X_train, y_train, X_test, y_test)

exec_time()
# Out:
# Best Value for k: 1
# F1-Score: 0.09116022099447513
# Execution time 00:00:37

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## KNN Tuned Model

# %%
#Run the improved model with best_k=1
start = time.time()

X, y = load_data('final_data.csv')                                         # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)                 # split data

KNT = Pipeline(steps=[('t', StandardScaler())
                      ,('m', KNeighborsClassifier(n_neighbors=1))]).fit(X_train, y_train) # define/fit model

KNT_probs = KNT.predict_proba(X_test)[:, 1]                                # predict probabilities for the positive 
y_pred = KNT.predict(X_test)                                               # predict 

fpr_KNN, tpr_KNT, thresholds = roc_curve(y_test, KNT_probs)                #calculate roc_auc score
KNT_precision, KNT_recall, _ = precision_recall_curve(y_test, KNT_probs)   #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, KNT_probs,  'KNT')
plot_pr_curve(y_test, y_pred, KNT_probs, 'KNT') 

exec_time()
# Out:
# Accuracy: 85.04 %
# Precision: 0.11256961018297534
# Recall: 0.10973245443970531
# F1-score: 0.11113292754761436
# R2: -0.9188260523595795
# MSE: 0.14956389586361835
# Prevalence: 0.08305801506541562
# Specificity: 0.9194264870526202
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.92      0.92      0.92     27689
#          YES       0.11      0.11      0.11      2579
#
#     accuracy                           0.85     30268
#    macro avg       0.51      0.51      0.51     30268
# weighted avg       0.85      0.85      0.85     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[25458  2231]
#  [ 2296   283]]
# f1=0.111 PR AUC=0.149
# Execution time 00:01:14

# %% [markdown]
# **Tuning result:**  Tuned KNN Precision Recall is PR AUC: 0.139 which has slightly improved from AUC: 0.098

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # DecisionTreeClassifier
#  area under the precision-recall metric. The problem is the shape of the AUPRC
# For DecisionTreeClassifier, replace predict with pred_proba; the latter serves the same role as decision_function.

# %%
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

DT = DecisionTreeClassifier().fit(X_train, y_train)           # define/fit model

# predict probabilities
DT_probs = DT.predict_proba(X_test)[:, 1]                        # predict probabilities for the positive outcome only
y_pred = DT.predict(X_test)                                      # predict

fpr_DT, tpr_DT, thresholds = roc_curve(y_test, DT_probs)              #calculate roc_auc score
DT_precision, DT_recall, _ = precision_recall_curve(y_test, DT_probs) #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, DT_probs,  'DT')
plot_pr_curve(y_test, y_pred, DT_probs, 'DT') 

exec_time()
# Out:
# Accuracy: 83.09 %
# Precision: 0.10781587890021625
# Recall: 0.13532376890267545
# F1-score: 0.12001375515818431
# R2: -1.1693288570745146
# MSE: 0.16908946742434253
# Prevalence: 0.1069446279899564
# Specificity: 0.8956986528946513
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.92      0.90      0.91     27689
#          YES       0.11      0.14      0.12      2579
#
#     accuracy                           0.83     30268
#    macro avg       0.51      0.52      0.51     30268
# weighted avg       0.85      0.83      0.84     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[24801  2888]
#  [ 2230   349]]
# f1=0.120 PR AUC=0.158
# Execution time 00:00:00

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Decision Tree Tuning Parameters

# %%
## ⏰ This cell may take a long time to run!
# Tune Decision Tree
# Instantiate DecisionTreeClassifier

start = time.time()
#define model
DT = DecisionTreeClassifier(criterion='entropy')

# define grid
dt_param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 2, 3, 4, 5, 6],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 3, 4, 5, 6],
    'max_features' : [10,15, 20, 22, 24, 25, 28, 30,35, 30, 35, 40, 45]
}

# evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# Instantiate GridSearchCV
dt_grid_search = GridSearchCV(estimator=DT, param_grid=dt_param_grid, cv=cv,  n_jobs=-1, scoring='roc_auc')

# execute the grid search
dt_grid_search.fit(X_train, y_train)


print("Best Parameter Combination Found During Grid Search:")
print(dt_grid_search.best_params_)


# report all configurations
means = dt_grid_search.cv_results_['mean_test_score']
stds = dt_grid_search.cv_results_['std_test_score']
params = dt_grid_search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('%f (%f) with: %r' % (mean, stdev, param))

exec_time()

"""
Best Parameter Combination Found During Grid Search:
{'criterion': 'entropy', 'max_depth': 5, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}
Execution time 00:23:04
"""
# Out:
# Best Parameter Combination Found During Grid Search:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.510796 (0.011001) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.520068 (0.014122) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.524178 (0.011602) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.517323 (0.011777) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.519228 (0.015246) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.528262 (0.011900) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.525030 (0.011674) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.524148 (0.015130) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.526397 (0.013436) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.528448 (0.015350) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.530562 (0.017812) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.527178 (0.016810) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.535635 (0.016292) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.532026 (0.016379) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.528889 (0.014412) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.535449 (0.014747) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.536355 (0.020120) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.540581 (0.017437) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.513182 (0.008092) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.516632 (0.009545) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.521866 (0.013803) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.522036 (0.014123) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.518262 (0.009753) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.529768 (0.013383) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.522338 (0.011879) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.523646 (0.014387) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.526412 (0.015491) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.525473 (0.015381) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.526496 (0.014510) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.530710 (0.012163) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.532090 (0.015470) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.531890 (0.016992) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.525317 (0.014903) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.533643 (0.013625) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.530174 (0.013429) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.538148 (0.017122) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.513388 (0.011046) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.515286 (0.010850) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.524155 (0.015411) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.518203 (0.010899) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.521624 (0.010561) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.524654 (0.015666) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.522719 (0.016367) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.520459 (0.012150) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.523511 (0.016715) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.518197 (0.010372) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.524886 (0.011766) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.529797 (0.015129) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.531188 (0.013092) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.529041 (0.013718) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.531879 (0.017394) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.531800 (0.011903) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.531810 (0.015372) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.532622 (0.015578) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.515345 (0.010037) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.515844 (0.012473) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.523241 (0.012814) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.517028 (0.013407) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.519702 (0.012731) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.522641 (0.015621) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.519603 (0.015497) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.522988 (0.011520) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.521136 (0.013527) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.523880 (0.014465) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.527108 (0.015256) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.525012 (0.014847) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.530979 (0.014542) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.530255 (0.012280) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.527798 (0.015917) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.526360 (0.015979) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.530796 (0.012382) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.533350 (0.013806) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.515224 (0.009850) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.516617 (0.011477) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.520950 (0.014629) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.519100 (0.012982) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.516827 (0.013525) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.526035 (0.015398) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.520611 (0.016847) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.519670 (0.012644) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.518208 (0.015137) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.527645 (0.012667) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.521054 (0.012905) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.530595 (0.015264) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.525304 (0.016433) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.525434 (0.016008) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.529525 (0.017081) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.536314 (0.014433) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.534381 (0.017924) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.532195 (0.013605) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.512771 (0.011354) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.520786 (0.012826) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.521678 (0.015249) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.519555 (0.012888) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.520405 (0.011395) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.526178 (0.014427) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.519762 (0.010569) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.521128 (0.012647) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.523571 (0.017264) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.527190 (0.014752) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.525728 (0.013311) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.523678 (0.011442) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.529929 (0.012553) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.524492 (0.013519) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.528345 (0.014306) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.527873 (0.016932) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.534213 (0.012088) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.534995 (0.015221) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.509983 (0.010615) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.517203 (0.011185) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.522597 (0.014546) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.520939 (0.013113) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.518754 (0.014054) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.523144 (0.016745) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.519209 (0.014076) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.517299 (0.014716) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.525760 (0.012255) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.526013 (0.012625) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.524939 (0.016012) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.522885 (0.014886) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.528670 (0.014250) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.529185 (0.015080) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.526265 (0.013974) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.534747 (0.013178) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.531332 (0.014657) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.531480 (0.017695) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.513514 (0.011246) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.516841 (0.010958) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.520371 (0.014240) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.512883 (0.009296) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.517574 (0.011534) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.521711 (0.014310) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.522921 (0.010356) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.516943 (0.013073) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.518987 (0.017646) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.526378 (0.015695) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.519944 (0.014918) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.530824 (0.012123) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.525150 (0.018272) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.526359 (0.013454) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.530544 (0.012886) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.529333 (0.013759) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.526191 (0.018162) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.531412 (0.013387) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.510443 (0.008115) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.513621 (0.012971) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.516966 (0.014125) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.515693 (0.012492) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.520190 (0.013639) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.522208 (0.013283) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.517494 (0.011575) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.516692 (0.012062) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.522942 (0.016627) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.521936 (0.018212) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.521013 (0.013921) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.525584 (0.014862) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.522892 (0.016213) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.526680 (0.015133) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.529350 (0.018290) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.532096 (0.014703) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.529821 (0.012365) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.523985 (0.015787) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.514661 (0.010767) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.513971 (0.009587) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.523185 (0.018062) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.517818 (0.014039) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.516221 (0.011086) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.523980 (0.015674) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.521501 (0.012511) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.521387 (0.013167) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.520057 (0.012177) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.520634 (0.011984) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.528382 (0.013038) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.523227 (0.015823) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.523430 (0.017905) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.525399 (0.011648) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.527719 (0.015807) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.530630 (0.015049) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.533486 (0.014114) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.529510 (0.014476) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.509817 (0.010249) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.510884 (0.010684) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.520669 (0.014619) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.518578 (0.011730) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.513193 (0.014167) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.522406 (0.012474) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.520117 (0.011488) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.519888 (0.014340) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.517635 (0.014225) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.521027 (0.018277) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.527143 (0.016828) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.522716 (0.013914) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.524441 (0.017304) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.528865 (0.012235) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.522352 (0.015574) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.528761 (0.013582) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.529502 (0.015983) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.527450 (0.018407) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.511815 (0.009131) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.514814 (0.012169) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.518692 (0.015519) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.514645 (0.012006) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.517603 (0.013370) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.519208 (0.013668) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.523484 (0.011832) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.519670 (0.014279) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.520427 (0.014163) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.521501 (0.014712) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.523663 (0.015143) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.524483 (0.016022) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.524656 (0.015259) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.528282 (0.014728) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.523524 (0.015971) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.527026 (0.016097) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.527754 (0.014675) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.526880 (0.011828) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.509232 (0.009357) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.511604 (0.014043) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.516892 (0.013685) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.513407 (0.011448) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.514247 (0.012818) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.518706 (0.015967) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.514619 (0.014974) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.515933 (0.014225) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.518117 (0.016612) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.521866 (0.016432) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.522763 (0.016030) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.524409 (0.014898) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.525464 (0.016552) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.526411 (0.016827) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.525678 (0.016857) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.525479 (0.013301) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.525151 (0.012880) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.525315 (0.012794) with: {'criterion': 'gini', 'max_depth': None, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.552036 (0.027055) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.555386 (0.026994) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.558450 (0.025686) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.564278 (0.027545) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.561128 (0.024844) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.554963 (0.025538) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.555010 (0.020869) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.565381 (0.027877) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.561177 (0.024902) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.565564 (0.026657) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.563496 (0.025192) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.560587 (0.027428) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.565487 (0.020691) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.555590 (0.030191) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.556945 (0.024863) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.565137 (0.021216) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.557649 (0.022089) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.555759 (0.027609) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.571256 (0.024092) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.565636 (0.025503) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.569919 (0.018147) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.568966 (0.021437) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.568857 (0.027279) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.567125 (0.016481) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.565690 (0.021595) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.565173 (0.024861) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.569389 (0.021610) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.563287 (0.028742) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.570223 (0.028823) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.563243 (0.018143) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.567516 (0.021710) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.571546 (0.021707) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.564908 (0.017850) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.564459 (0.024081) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.568040 (0.019568) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.572699 (0.022164) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 15, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.574100 (0.021069) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.578508 (0.019605) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.572464 (0.021431) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.570691 (0.023145) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.573105 (0.021307) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.572773 (0.022481) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.570868 (0.019914) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.569324 (0.024476) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.576929 (0.019092) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.573829 (0.020604) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.575888 (0.022247) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.573213 (0.018843) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.572494 (0.024282) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.567097 (0.021849) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.578911 (0.017300) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.574865 (0.017898) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.574663 (0.022745) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.570850 (0.023031) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 20, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.579349 (0.024432) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.574462 (0.017355) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.574948 (0.021873) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.571135 (0.020581) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.571869 (0.023532) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.574000 (0.024155) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.573192 (0.022652) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.573956 (0.022010) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.577128 (0.021461) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.572107 (0.024617) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.575907 (0.017886) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.572328 (0.017900) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.578866 (0.018921) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.579608 (0.016849) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.575943 (0.021184) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.577973 (0.021304) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.572814 (0.021256) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.571395 (0.020323) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 22, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.579943 (0.020829) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.575444 (0.020660) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.574147 (0.024183) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.568028 (0.017097) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.575482 (0.017774) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.575630 (0.018280) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.576063 (0.023789) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.575708 (0.021035) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.569688 (0.020103) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.575134 (0.019342) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.577142 (0.018548) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.566052 (0.019462) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.576770 (0.019428) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.571212 (0.019156) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.576562 (0.020231) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.571134 (0.021501) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.577644 (0.017640) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.576019 (0.021713) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 24, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.577204 (0.021622) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.573465 (0.017533) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.578308 (0.019472) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.575772 (0.018497) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.577625 (0.020757) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.580009 (0.018100) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.576687 (0.019582) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.578238 (0.014305) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.574006 (0.020266) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.575401 (0.017636) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.579763 (0.019743) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.577563 (0.016874) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.573959 (0.018549) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.575178 (0.021053) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.571279 (0.018888) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.578830 (0.024022) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.578806 (0.021899) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.573317 (0.016129) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 25, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.577393 (0.017342) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.577510 (0.017389) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.576684 (0.019037) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.575632 (0.018080) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.577660 (0.017292) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.571349 (0.016975) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.579424 (0.018883) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.573413 (0.017593) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.574384 (0.017348) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.571227 (0.024988) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.580284 (0.018636) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.577701 (0.018950) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.574294 (0.018372) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.575681 (0.015311) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.572933 (0.018474) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.575751 (0.020791) with: {'criterion': 'gini', 'max_depth': 2, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 2}
# ...
# 0.596953 (0.021266) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.595894 (0.018341) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.595477 (0.023148) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.600289 (0.020195) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.599249 (0.017980) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.599763 (0.020130) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.598592 (0.020867) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.598586 (0.017242) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.599872 (0.017692) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 28, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.598802 (0.018775) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.597569 (0.019038) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.597164 (0.022571) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.597464 (0.018588) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.599162 (0.019316) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.599012 (0.017396) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.596191 (0.018618) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.596905 (0.017160) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.599534 (0.017248) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.598962 (0.021428) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.601622 (0.019633) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.599106 (0.019560) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.595542 (0.018299) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597655 (0.019222) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.599368 (0.019499) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.600255 (0.020403) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.598445 (0.019023) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.595772 (0.016426) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.594987 (0.020271) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.599328 (0.019288) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.598523 (0.017355) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.597189 (0.018949) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.598127 (0.020280) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.595189 (0.019765) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.596834 (0.020086) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.596802 (0.018024) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.603917 (0.017286) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.598393 (0.019929) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.596479 (0.020240) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.596219 (0.018591) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.595883 (0.015516) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597746 (0.017547) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.598597 (0.017303) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.597101 (0.016544) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.595357 (0.018698) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.598248 (0.017880) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.599329 (0.024546) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.593888 (0.021503) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.596983 (0.019569) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.599586 (0.016861) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.596730 (0.022606) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.596896 (0.019791) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.597671 (0.018353) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.597989 (0.018438) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.601587 (0.016793) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.602994 (0.018221) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.596425 (0.018013) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.600131 (0.019925) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.596389 (0.012784) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597723 (0.015063) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.599805 (0.020627) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.597632 (0.014189) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.598018 (0.018961) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.597473 (0.020773) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 30, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.597283 (0.016700) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.599473 (0.018653) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.602023 (0.020894) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.599002 (0.017442) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.595309 (0.019385) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.594323 (0.017444) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.592996 (0.017033) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.598353 (0.019788) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.594865 (0.017599) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.598908 (0.021560) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.596693 (0.017425) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.597970 (0.017355) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.599614 (0.016715) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597302 (0.017368) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.600669 (0.020612) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.596002 (0.014402) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.595505 (0.017713) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.597228 (0.019440) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 35, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.598780 (0.019845) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.599221 (0.017538) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.601124 (0.018999) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.597748 (0.020290) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.597896 (0.016873) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.600998 (0.019359) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.600109 (0.018909) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.596769 (0.016965) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.597565 (0.019264) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.595773 (0.020143) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.597758 (0.018026) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.595288 (0.020390) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.597917 (0.018832) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597843 (0.020434) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.596088 (0.019177) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.596142 (0.019932) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.598984 (0.019762) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.594696 (0.016687) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 40, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.598040 (0.019263) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.597656 (0.019544) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 5}
# 0.598851 (0.019160) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.598055 (0.018346) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.598164 (0.018462) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.598305 (0.018309) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.598161 (0.018103) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.598397 (0.017962) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.598179 (0.017911) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.597438 (0.018029) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.597443 (0.018001) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 5}
# 0.597261 (0.018072) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.597950 (0.018201) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.597950 (0.018407) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.597823 (0.018359) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.597322 (0.018464) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.597291 (0.018450) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 5}
# 0.597350 (0.018480) with: {'criterion': 'entropy', 'max_depth': 6, 'max_features': 45, 'min_samples_leaf': 6, 'min_samples_split': 10}
# Execution time 00:15:33
# "\nBest Parameter Combination Found During Grid Search:\n{'criterion': 'entropy', 'max_depth': 5, 'max_features': 35, 'min_samples_leaf': 2, 'min_samples_split': 2}\nExecution time 00:23:04\n"

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Decision Tree Tuned Model

# %%
#Run Tuned Model with Best Parameter Combination Found During Grid Search:

start = time.time()

X, y = load_data('final_data.csv')                                              # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)                      # split data

# sm = SMOTE(random_state=27, ratio=1.0)                                        # SMOTE
# X_train, y_train = sm.fit_sample(X_train, y_train)

DTT = DecisionTreeClassifier(criterion='entropy'
                             , max_depth= 5
                             , min_samples_leaf= 2
                             , min_samples_split= 2).fit(X_train, y_train)  

DTT_probs= DTT.predict_proba(X_test)[:, 1]             # predict probabilities for the positive outcome only

y_pred = DTT.predict(X_test)                                                    # predict
fpr_DTT, tpr_DTT, thresholds = roc_curve(y_test, DTT_probs)                     #calculate roc_auc score
DTT_precision, DTT_recall, _ = precision_recall_curve(y_test, DTT_probs)        #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, DTT_probs,  'DTT')
plot_pr_curve(y_test, y_pred, DTT_probs, 'DTT') 

exec_time()
# Out:
# Accuracy: 91.45 %
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# R2: -0.09738030694918298
# MSE: 0.08553587947667504
# Prevalence: 0.00033038192150125544
# Specificity: 0.9996388457510202
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.00      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.46      0.50      0.48     30268
# weighted avg       0.84      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27679    10]
#  [ 2579     0]]
# f1=0.000 PR AUC=0.125
# Execution time 00:00:00

# %% [markdown]
# **Tuning Results:**
# Pre-tuned  DT Scores:
# DTT ROC AUC 0.516
# DTT PR AUC: 0.155
# Tuned DT Scores:
# DTT ROC AUC 0.608
# DTT PR AUC: 0.128

# %% [markdown]
# **Tuning result:** While accuracy slightly decreased, we slightly improved the AUC, Precision score, Recall, F1- score with some tuning and decreased prediction errors (MAE & MSE)

# %% [markdown]
# Mean Absolute Error (MAE): MAE measures the average magnitude of the errors in a set of predictions, without considering their direction. It’s the average over the test sample of the absolute differences between prediction and actual observation where all individual differences have equal weight.
# Root mean squared error (RMSE): RMSE is a quadratic scoring rule that also measures the average magnitude of the error. It’s the square root of the average of squared differences between prediction and actual observation.
# Both MAE and RMSE express average model prediction error in units of the variable of interest. Both metrics can range from 0 to ∞ and are indifferent to the direction of errors. They are negatively-oriented scores, which means lower values are better.

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # RandomForestClassifier

# %%
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data
sm = SMOTE(random_state=27, ratio=1.0)                                        # SMOTE
X_train, y_train = sm.fit_sample(X_train, y_train)
RF = RandomForestClassifier(n_estimators=10, class_weight='balanced').fit(X_train, y_train)  # define/fit model
 # define/fit model

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)


#Evaluate the model using roc_auc scoring
scores = cross_val_score(RF, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)


RF_probs= RF.predict_proba(X_test)[:, 1]                   # predict probabilities for the positive outcome only

y_pred = RF.predict(X_test)
fpr_RF, tpr_RF, thresholds = roc_curve(y_test, RF_probs) 
RF_precision, RF_recall, _ = precision_recall_curve(y_test, RF_probs) 

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, RF_probs,  'RF')
plot_pr_curve(y_test, y_pred, RF_probs, 'RF') 

exec_time()
# Out:
# Accuracy: 91.23 %
# Precision: 0.1262135922330097
# Recall: 0.005040713454827452
# F1-score: 0.009694258016405666
# R2: -0.12577910206915033
# MSE: 0.08774943835073344
# Prevalence: 0.003402933791462931
# Specificity: 0.9967496117591823
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.95     27689
#          YES       0.13      0.01      0.01      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.52      0.50      0.48     30268
# weighted avg       0.85      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27599    90]
#  [ 2566    13]]
# f1=0.010 PR AUC=0.105
# Execution time 00:00:04

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Random Forest Tuning Parameters

# %%
## ⏰ This cell may take a long time to run!
# grid search class weights with RandomForestClassifier for imbalance classification
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

RF = RandomForestClassifier(criterion='entropy')                      # define model

# define grid
rf_param_grid = {
    'n_estimators': [10, 30, 100],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 2, 6, 10],
    'min_samples_split': [5, 10],
    'min_samples_leaf': [3, 6]
}

# evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# define grid search
rf_grid = GridSearchCV(estimator=RF, param_grid=rf_param_grid, cv=cv, n_jobs=-1, scoring='roc_auc')
# execute the grid search
rf_grid_result = rf_grid.fit(X_train, y_train)
               
# print results
print("Best AUC score: %f using  %s" % (rf_grid_result.best_score_, rf_grid_result.best_params_))

# report all configurations
means = rf_grid_result.cv_results_['mean_test_score']
stds = rf_grid_result.cv_results_['std_test_score']
params = rf_grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('%f (%f) with: %r' % (mean, stdev, param))
    
exec_time()
# Out:
# Best AUC score: 0.628369 using  {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.575539 (0.014307) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.593993 (0.013406) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.610799 (0.015901) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.577528 (0.018287) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.594023 (0.017296) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.610851 (0.014612) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.587835 (0.012553) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.607833 (0.014356) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.616501 (0.017396) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.589548 (0.015677) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.605660 (0.015374) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.618195 (0.015100) with: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.604851 (0.020195) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.614382 (0.017280) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.618028 (0.017032) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.608408 (0.019013) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.615138 (0.017765) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.618550 (0.016671) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.607181 (0.022122) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.615173 (0.018557) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.618012 (0.016640) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.604055 (0.021508) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.615555 (0.017093) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.617904 (0.017708) with: {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.616663 (0.017628) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.622128 (0.015414) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.624011 (0.016819) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.616357 (0.018462) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.621883 (0.017241) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.625653 (0.017743) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.615508 (0.020662) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.622034 (0.017664) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.625388 (0.016948) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.614664 (0.018609) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.622237 (0.018606) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.625900 (0.016578) with: {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.607207 (0.017168) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.621345 (0.017036) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.625765 (0.016029) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.608153 (0.018972) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.620463 (0.015880) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.626326 (0.016329) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.609787 (0.014743) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.620185 (0.016075) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.626675 (0.016045) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.606300 (0.016766) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.620649 (0.015802) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.625771 (0.016274) with: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.578955 (0.019791) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.597467 (0.018026) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.610036 (0.014354) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.579714 (0.017187) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.602994 (0.014120) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.611897 (0.015618) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.590287 (0.016503) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.606783 (0.014764) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.616307 (0.013573) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.589484 (0.015801) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.605906 (0.015214) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.621114 (0.016529) with: {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.606395 (0.016748) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.615225 (0.017490) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.619031 (0.018036) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.609042 (0.017051) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.617617 (0.018762) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.618038 (0.016729) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.607722 (0.018735) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.613341 (0.017108) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.618108 (0.017526) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.607323 (0.019821) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.613975 (0.017935) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.617851 (0.017357) with: {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.612903 (0.015888) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.623064 (0.017476) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.625146 (0.017003) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.617519 (0.017668) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.621781 (0.016849) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.624903 (0.016221) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.615475 (0.016629) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.622479 (0.016887) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.625517 (0.017421) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.611846 (0.016649) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.622446 (0.015993) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.625335 (0.016854) with: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# 0.609230 (0.016690) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 10}
# 0.622793 (0.015192) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
# 0.625412 (0.016209) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}
# 0.607334 (0.015777) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.621244 (0.015100) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 30}
# 0.627438 (0.016765) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.606564 (0.017893) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 10}
# 0.620765 (0.018398) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 30}
# 0.628369 (0.016002) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 100}
# 0.611929 (0.016716) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 10}
# 0.621370 (0.015282) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 30}
# 0.626329 (0.016073) with: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 100}
# Execution time 00:05:18

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # RandomForestClassifier Tuned Model

# %%
## ⏰ This cell may take a long time to run!
#Run tuned model with Class weighting and Optimal Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 30}
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

# define model
RFT = RandomForestClassifier(criterion='gini'                         # define/fit model
                             ,n_jobs = -1
                             ,min_samples_leaf = 3
                             ,n_estimators= 30
                             ,min_samples_split=5
                             ,class_weight='balanced').fit(X_train, y_train)

# # define evaluation procedure
# cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# #Evaluate the model using roc_auc scoring
# scores = cross_val_score(RFT, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# print_mean_rocauc_scores(scores)

# predict probabilities
RFT_probs = RFT.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = RFT.predict(X_test)                             # predict

fpr_RFT, tpr_RFT, thresholds = roc_curve(y_test, RFT_probs)              #calculate roc_auc score
RFT_precision, RFT_recall, _ = precision_recall_curve(y_test, RFT_probs) #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, RFT_probs,  'RFT')
plot_pr_curve(y_test, y_pred, RFT_probs, 'RFT') 

exec_time()
# Out:
# Accuracy: 90.4 %
# Precision: 0.1749502982107356
# Recall: 0.03412175261729353
# F1-score: 0.05710577547047372
# R2: -0.2317447555018639
# MSE: 0.09600898638826483
# Prevalence: 0.01661821065151315
# Specificity: 0.9850120986673409
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.92      0.99      0.95     27689
#          YES       0.17      0.03      0.06      2579
#
#     accuracy                           0.90     30268
#    macro avg       0.55      0.51      0.50     30268
# weighted avg       0.85      0.90      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27274   415]
#  [ 2491    88]]
# f1=0.057 PR AUC=0.119
# Execution time 00:00:01

# %% [markdown]
# **Tuning result:**  We see an improved RF AUC with some tuning of the model:
# From ROC AUC 0.552  to ROC AUC 0.620
# From PR  AUC  0.107 to PR  AUC 0.129
# Like the previous models, we have a problem of high training score but low test score (over-fitting), our model is not generalizing properly.
# + Apply Sub-sample the positive samples in order to have a 50/50 dataset.
# + Use other algorithm that deals naturally with unbalanced datasets, like anomaly detection methods.

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %%
#Random Forest Feature Selection - Important Features 
feature_names = X_train.columns
feature_imports = RFT.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"])
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,18))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest')
plt.show()

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # BaggingClassifier

# %%
# Bagged Decision Trees for Classification
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

cart = DecisionTreeClassifier()                                       # define/fit model
num_trees = 100
BG = BaggingClassifier(base_estimator=cart, n_estimators=num_trees
                       , random_state=2).fit(X_train, y_train)   


BG_probs= BG.predict_proba(X_test)[:, 1]                  # predict probabilities for the positive outcome only

y_pred = BG.predict(X_test)                                           # predict 
fpr_BG, tpr_BG, thresholds = roc_curve(y_test, BG_probs)              #calculate roc_auc score
BG_precision, BG_recall, _ = precision_recall_curve(y_test, BG_probs) #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, BG_probs,  'BG')
plot_pr_curve(y_test, y_pred, BG_probs, 'BG') 

exec_time()
# Out:
# Accuracy: 91.38 %
# Precision: 0.1875
# Recall: 0.0034897246994959287
# F1-score: 0.0068519223448800905
# R2: -0.10585755922380002
# MSE: 0.08619664331967755
# Prevalence: 0.0015858332232060262
# Specificity: 0.998591498428979
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.95     27689
#          YES       0.19      0.00      0.01      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.55      0.50      0.48     30268
# weighted avg       0.85      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27650    39]
#  [ 2570     9]]
# f1=0.007 PR AUC=0.113
# Execution time 00:00:12

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # BalancedBaggingClassifier

# %%
## ⏰ This cell may take a long time to run!
# BalancedBaggingClassifier for Classification - random undersampling strategy on the majority class within a bootstrap sample in order to balance the two classes
start = time.time()

X, y = load_data('final_data.csv')                                        # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)                # split data

cart = DecisionTreeClassifier(criterion='entropy'                         # define/fit model      
                              , max_depth= 5
                              , min_samples_leaf= 2
                              , min_samples_split= 2)
num_trees = 100
#BBG = BalancedBaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=2).fit(X_train, y_train) 

BBG = Pipeline(steps=[('t', StandardScaler()),('m',BalancedBaggingClassifier(base_estimator=cart, n_estimators=num_trees, random_state=2).fit(X_train, y_train))])
BBG.fit(X_train, y_train) 
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
scores = cross_val_score(BBG, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
BBG_probs = BBG.predict_proba(X_test)[:, 1]               # predict probabilities for the positive outcome only

y_pred = BBG.predict(X_test)                              # predict
fpr_BBG, tpr_BBG, thresholds = roc_curve(y_test, BBG_probs)              #calculate roc_auc score
BBG_precision, BBG_recall, _ = precision_recall_curve(y_test, BBG_probs) #calculate pr_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, BBG_probs,  'BBG')
plot_pr_curve(y_test, y_pred, BBG_probs, 'BBG') 

exec_time()
# Out:
# Accuracy: 69.21000000000001 %
# Precision: 0.1320672342283344
# Recall: 0.46917409848778596
# F1-score: 0.20611532237458477
# R2: -2.950823422585297
# MSE: 0.30794898903132023
# Prevalence: 0.30269591647945027
# Specificity: 0.7128101412113114
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.94      0.71      0.81     27689
#          YES       0.13      0.47      0.21      2579
#
#     accuracy                           0.69     30268
#    macro avg       0.53      0.59      0.51     30268
# weighted avg       0.87      0.69      0.76     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[19737  7952]
#  [ 1369  1210]]
# f1=0.206 PR AUC=0.137
# Execution time 00:01:44

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # Gradient Boosting
# Another way that we can improve the performance of algorithms on this problem is by using ensemble methods. In this section we will evaluate four different ensemble machine learning algorithms, two boosting and two bagging methods:
# 􏰀 Boosting Methods: AdaBoost (AB) and Gradient Boosting (GBM). 􏰀 Bagging Methods: Random Forests (RF) and Extra Trees (ET).
# We will use the same test harness as before, 10-fold cross validation. No data standardization is used in this case because all four ensemble algorithms are based on decision trees that are less sensitive to data distributions.
#
#
# Finalize Model (use all training data and confirm using validation dataset).  We can see that we achieve an accuracy of nearly 86% on the held-out validation dataset. A score that matches closely to our expectations estimated above during the tuning of SVM

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # ADABoostClassifier

# %%
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

AB = AdaBoostClassifier(n_estimators=50, learning_rate=1).fit(X_train, y_train)      # define/fit model

# predict probabilities
AB_probs = AB.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only

y_pred = AB.predict(X_test)                                           # predict
fpr_AB, tpr_AB, thresholds = roc_curve(y_test, AB_probs)              #calculate roc_auc score
AB_precision, AB_recall, _ = precision_recall_curve(y_test, AB_probs) #calculate pr_auc score 

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, AB_probs,  'AB')
plot_pr_curve(y_test, y_pred, AB_probs, 'AB') 

exec_time()
# Out:
# Accuracy: 91.47 %
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# R2: -0.09398940603933625
# MSE: 0.08527157393947403
# Prevalence: 6.60763843002511e-05
# Specificity: 0.9999277691502041
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.00      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.46      0.50      0.48     30268
# weighted avg       0.84      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27687     2]
#  [ 2579     0]]
# f1=0.000 PR AUC=0.135
# Execution time 00:00:01

# %% [markdown]
# **Result** Train & Test has around the same score. No evidence of overfitting. Let us see if we can improve the auc further by tuning the model

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # ADABoostClassifier Tuned Model

# %% [markdown]
# We can see the AdaBoost ensemble with a logistic regression weak model achieves a classification accuracy of about 91.5 percent on this test dataset.  Using Different Base Learners
# I have used SVC as a base estimator. You can use any ML learner as base estimator if it accepts sample weight such as Decision Tree, Support Vector Classifier.

# %% [markdown]
# The results show that, given the selected grid search ranges, the optimal parameters (those that provide the best cross-validation fit for the data) are 230 estimators with a learning rate of 0.05. The plot of the model of these parameters indeed shows that the fit looks might fine.
# Pros
# AdaBoost is easy to implement. It iteratively corrects the mistakes of the weak classifier and improves accuracy by combining weak learners. You can use many base classifiers with AdaBoost. AdaBoost is not prone to overfitting. This can be found out via experiment results, but there is no concrete reason available.
#
# Cons
# AdaBoost is sensitive to noise data. It is highly affected by outliers because it tries to fit each point perfectly. AdaBoost is slower compared to XGBoost.

# %%
start = time.time()

X, y = load_data('final_data.csv')                                     # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)             # split data

ABT = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1)     # define/fit model
                         , n_estimators=40, learning_rate=1.0).fit(X_train, y_train) 

ABT_probs = ABT.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only

y_pred = ABT.predict(X_test)                                            # predict
fpr_ABT, tpr_ABT, thresholds = roc_curve(y_test, ABT_probs)              #calculate roc_auc score
ABT_precision, ABT_recall, _ = precision_recall_curve(y_test, ABT_probs) #calculate roc_auc score

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, ABT_probs,  'ABT')
plot_pr_curve(y_test, y_pred, ABT_probs, 'ABT') 

exec_time()
# Out:
# Accuracy: 91.47 %
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# R2: -0.09398940603933625
# MSE: 0.08527157393947403
# Prevalence: 6.60763843002511e-05
# Specificity: 0.9999277691502041
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.00      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.46      0.50      0.48     30268
# weighted avg       0.84      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27687     2]
#  [ 2579     0]]
# f1=0.000 PR AUC=0.134
# Execution time 00:00:01

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# **Tuning Result:**
# AB ROC AUC 0.623
# AB PR AUC: 0.132
# Tuned ADABoost Classifier:
# ABT ROC AUC 0.624
# ABT PR AUC: 0.134

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # GradientBoostingClassifier

# %%
start = time.time()

X, y = load_data('final_data.csv')                                    # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)            # split data

GB = GradientBoostingClassifier().fit(X_train, y_train)               # define/fit model

GB_probs= GB.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only

y_pred = GB.predict(X_test)                                           # predict
fpr_GB, tpr_GB, thresholds = roc_curve(y_test, GB_probs)              #calculate roc_auc score
GB_precision, GB_recall, _ = precision_recall_curve(y_test, GB_probs) #calculate roc_auc score 

#Summarize:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, GB_probs,  'GB')
plot_pr_curve(y_test, y_pred, GB_probs, 'GB') 

exec_time()
# Out:
# Accuracy: 91.47999999999999 %
# Precision: 0.5
# Recall: 0.0019387359441644049
# F1-score: 0.0038624951718810355
# R2: -0.09314168081187457
# MSE: 0.08520549755517379
# Prevalence: 0.00033038192150125544
# Specificity: 0.9998194228755102
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.50      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.71      0.50      0.48     30268
# weighted avg       0.88      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27684     5]
#  [ 2574     5]]
# f1=0.004 PR AUC=0.140
# Execution time 00:00:03
# '\nResult:\nMean ROC AUC: 0.622\nGB ROC AUC 0.630\nGB PR AUC: 0.140\nExecution time 00:01:03\n'

# %%
# def display_acc_and_f1_score(true, preds, model_name):
#     acc = accuracy_score(true, preds)
#     f1 = f1_score(true, preds)
#     print("Model: {}".format(model_name))
#     print("Accuracy: {}".format(acc))
#     print("F1-Score: {}".format(f1))
    
# print("Training Metrics")
# display_acc_and_f1_score(y_train, AB_train_preds, model_name='AdaBoost')
# print("")
# display_acc_and_f1_score(y_train, GB_train_preds, model_name='Gradient Boosted Trees')
# print("")
# print("Testing Metrics")
# display_acc_and_f1_score(y_test, AB_test_preds, model_name='AdaBoost')
# print("")
# display_acc_and_f1_score(y_test, GB_test_preds, model_name='Gradient Boosted Trees')

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # XGBoostClassifier

# %%
start = time.time()

X, y = load_data('final_data.csv')                                      # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)              # split data

XGB = XGBClassifier().fit(X_train, y_train)                              # define/fit model

XGB_probs = XGB.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = XGB.predict(X_test)                                             # predict

fpr_XGB, tpr_XGB, thresholds = roc_curve(y_test, XGB_probs)              # calculate roc_auc score
XGB_precision, XGB_recall, _ = precision_recall_curve(y_test, XGB_probs) # calculate pr_auc score 

#Summary report:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, XGB_probs,  'XGB')
plot_pr_curve(y_test, y_pred, XGB_probs, 'XGB')   
    
exec_time()
# Out:
# Accuracy: 91.49000000000001 %
# Precision: 0.7142857142857143
# Recall: 0.0019387359441644049
# F1-score: 0.003866976024748647
# R2: -0.09187009297068194
# MSE: 0.0851063829787234
# Prevalence: 0.00023126734505087883
# Specificity: 0.9999277691502041
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.71      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.81      0.50      0.48     30268
# weighted avg       0.90      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27687     2]
#  [ 2574     5]]
# f1=0.004 PR AUC=0.141
# Execution time 00:00:06

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Tuning XGBoost

# %%
# ⏰ This cell may take a long time to run!
start = time.time()

param_grid = {
    'learning_rate': [0.1, 0.2],
    'max_depth': [6],
    'min_child_weight': [1, 2],
    'subsample': [0.5, 0.7],
    'n_estimators': [100],
}

grid_XGBt = GridSearchCV(XGB, param_grid, scoring='roc_auc', cv=cv, n_jobs=1)
grid_XGBt.fit(X_train, y_train)

best_XBG_params = grid_XGBt.best_params_

print('Grid Search found the following optimal parameters: ')
for param_name in sorted(best_XBG_params.keys()):
    print('%s: %r' % (param_name, best_XBG_params[param_name]))

XGBt_train_preds = grid_XGBt.predict(X_train)
XGBt_test_preds = grid_XGBt.predict(X_test)
training_accuracy = accuracy_score(y_train, XGBt_train_preds)
test_accuracy = accuracy_score(y_test, XGBt_test_preds)

print('')
print('Training Accuracy: {:.4}%'.format(training_accuracy * 100))
print('Validation accuracy: {:.4}%'.format(test_accuracy * 100))
print('')
print_scores(y_test, XGBt_test_preds)
fpr_XGBt, tpr_XGBt, thresholds = roc_curve(y_test, XGBt_test_preds)

exec_time()
# Out:
# Grid Search found the following optimal parameters:
# learning_rate: 0.1
# max_depth: 6
# min_child_weight: 2
# n_estimators: 100
# subsample: 0.7
#
# Training Accuracy: 91.55%
# Validation accuracy: 91.48%
#
# Accuracy: 91.47999999999999 %
# Precision: 0.5
# Recall: 0.0011632415664986429
# F1-score: 0.002321083172147002
# R2: -0.09314168081187457
# MSE: 0.08520549755517379
# Prevalence: 0.00019822915290075327
# Specificity: 0.9998916537253061
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.50      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.71      0.50      0.48     30268
# weighted avg       0.88      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27686     3]
#  [ 2576     3]]
# Execution time 00:29:39

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Tuned XGBoost

# %%
#Run Tuned XGBOsst model with grid search best parameters
start = time.time()

X, y = load_data('final_data.csv')                                           # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)                   # split data

XGBT = XGBClassifier(learning_rate= 0.1, max_depth= 6, min_child_weight= 2   # define/fit model
                     ,n_estimators= 100, subsample= 0.7).fit(X_train, y_train)

XGBT_probs = XGBT.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = XGBT.predict(X_test)                                               # predict

fpr_XGBT, tpr_XGBT, thresholds = roc_curve(y_test, XGBT_probs)              # calculate roc_auc score
XGBT_precision, XGBT_recall, _ = precision_recall_curve(y_test, XGBT_probs) # calculate pr_auc score

#Summary report:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, XGBT_probs,  'XGBT')
plot_pr_curve(y_test, y_pred, XGBT_probs, 'XGBT') 

exec_time()
# Out:
# Accuracy: 91.47999999999999 %
# Precision: 0.5
# Recall: 0.0011632415664986429
# F1-score: 0.002321083172147002
# R2: -0.09314168081187457
# MSE: 0.08520549755517379
# Prevalence: 0.00019822915290075327
# Specificity: 0.9998916537253061
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.91      1.00      0.96     27689
#          YES       0.50      0.00      0.00      2579
#
#     accuracy                           0.91     30268
#    macro avg       0.71      0.50      0.48     30268
# weighted avg       0.88      0.91      0.87     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[27686     3]
#  [ 2576     3]]
# f1=0.002 PR AUC=0.136
# Execution time 00:00:09

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # SVM Classifier

# %%
## ⏰ This cell may take a VERY long time to run!

start = time.time()

X, y = load_data('final_data.csv')                                       # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)               # split data

SVC_cl = SVC(gamma='scale' ,probability =True                            # define/fit model
                           ,class_weight= {0: 1, 1: 10}).fit(X_train, y_train)

SVC_probs= SVC_cl.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = SVC_cl.predict(X_test)                            # predict

fpr_SVC, tpr_SVC, thresholds = roc_curve(y_test, SVC_probs)              # calculate roc auc
SVC_precision, SVC_recall, _ = precision_recall_curve(y_test, SVC_probs) # calculate pr auc

#Summary report:
print_scores(y_test, y_pred)
plot_roc_curve(y_test, SVC_probs,  'SVC_cl')
plot_pr_curve(y_test, y_pred, SVC_probs, 'SVC_cl') 

exec_time()
# Out:
# Accuracy: 69.74000000000001 %
# Precision: 0.12612203158731963
# Recall: 0.43039937960449787
# F1-score: 0.19507908611599298
# R2: -2.8825815417746297
# MSE: 0.30262984009515
# Prevalence: 0.2907691291132549
# Specificity: 0.7222362671096826
# ---------------------------------------------------------------------
#
#  Classification Report:
#               precision    recall  f1-score   support
#
#           NO       0.93      0.72      0.81     27689
#          YES       0.13      0.43      0.20      2579
#
#     accuracy                           0.70     30268
#    macro avg       0.53      0.58      0.50     30268
# weighted avg       0.86      0.70      0.76     30268
#
# ---------------------------------------------------------------------
# Confusion matrix:
#  [[19998  7691]
#  [ 1469  1110]]
# f1=0.195 PR AUC=0.119
# Execution time 00:08:52

# %% [markdown]
# # Tuning SVC

# %%
# ⏰ This cell may take a long time to run!
start = time.time()
X, y = load_data('final_data.csv')  
# grid search class weights with svm for imbalance classification

# define model
model = SVC(gamma='scale')
# define grid
balance = [{0:100,1:1}, {0:10,1:1}, {0:1,1:1}, {0:1,1:10}, {0:1,1:100}] 
param_grid = dict(class_weight=balance)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search for SVM
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X, y)
# report the best configuration
print('Best: %f using %s' % (grid_result.best_score_, grid_result.best_params_)) # report all configurations
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print('%f (%f) with: %r' % (mean, stdev, param))

exec_time()

"""
RESULT:
Best: 0.618217 using {'class_weight': {0: 1, 1: 10}}
Execution time 03:12:28
"""
# Out:
# Best: 0.618217 using {'class_weight': {0: 1, 1: 10}}
# 0.529865 (0.026574) with: {'class_weight': {0: 100, 1: 1}}
# 0.529865 (0.026574) with: {'class_weight': {0: 10, 1: 1}}
# 0.514058 (0.025971) with: {'class_weight': {0: 1, 1: 1}}
# 0.618217 (0.010398) with: {'class_weight': {0: 1, 1: 10}}
# 0.532355 (0.016765) with: {'class_weight': {0: 1, 1: 100}}
# Execution time 02:13:50
# "\nRESULT:\nBest: 0.618217 using {'class_weight': {0: 1, 1: 10}}\nExecution time 03:12:28\n"

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # Compare ROC Curves

# %%
start = time.time()

#compare the ROC curve between different models
plt.figure(figsize=(10,8))
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

print('AUC Logistic regression: {}'.format(auc(fpr_LR, tpr_LR,)))
print('AUC Tuned Logistic regression: {}'.format(auc(fpr_LRt, tpr_LRt,))) 
# print('AUC KNearestNeighbors: {}'.format(auc(fpr_KNN, tpr_KNN,)))
# print('AUC KNearestNeighbors: {}'.format(auc(fpr_KNT, tpr_KNT,)))
print('AUC Decision Tree: {}'.format(auc(fpr_DT, tpr_DT,)))
print('AUC Tuned Decision Tree: {}'.format(auc(fpr_DTT, tpr_DTT,)))
print('AUC Randomforest: {}'.format(auc(fpr_RF, tpr_RF,)))
print('AUC Tuned Randomforest: {}'.format(auc(fpr_RFT, tpr_RFT,)))
print('AUC Bagged Tree Classifier: {}'.format(auc(fpr_BG, tpr_BG,)))
print('AUC Balanced Bagged Tree Classifier: {}'.format(auc(fpr_BBG, tpr_BBG,)))
print('AUC ADABoost: {}'.format(auc(fpr_AB, tpr_AB,)))
print('AUC Tuned ADABoost: {}'.format(auc(fpr_ABT, tpr_ABT,)))
print('AUC Gradient Boosting: {}'.format(auc(fpr_GB, tpr_GB,)))
print('AUC XGBoost: {}'.format(auc(fpr_XGB, tpr_XGB,)))
print('AUC Tuned XGBoost: {}'.format(auc(fpr_XGBT, tpr_XGBT,)))
print('AUC SVC: {}'.format(auc(fpr_SVC, tpr_SVC,)))


lw = 2
plt.plot(fpr_LR, tpr_LR, label='Logistic regression')
plt.plot(fpr_LRt, tpr_LRt, label='Tuned Logistic regression')
# plt.plot(fpr_KNN, tpr_KNN, label='KNearestNeighbors')
# plt.plot(fpr_KNT, tpr_KNT, label='KNearestNeighbors')
plt.plot(fpr_DT, tpr_DT, label='Decision Tree')
plt.plot(fpr_DTT, tpr_DTT,label='Tuned Decision Tree')
plt.plot(fpr_RF, tpr_RF, label='Randomforest Classifier')
plt.plot(fpr_RFT, tpr_RFT, label='Tuned Randomforest Classifier')
plt.plot(fpr_BG, tpr_BG, label='Bagged Decision Tree Classifier')
plt.plot(fpr_BBG, tpr_BBG, label='Balanced Bagged Tree Classifier')
plt.plot(fpr_AB, tpr_AB, label='ADABoost Classifier')
plt.plot(fpr_ABT, tpr_ABT, label='Tuned ADABoost Classifier')
plt.plot(fpr_GB, tpr_GB, label='Gradient Boosting Classifier')
plt.plot(fpr_XGB, tpr_XGB, label='XGBoost Classifier',linestyle='--',color='navy')
plt.plot(fpr_XGBT, tpr_XGBT, label='Tuned XGBoost Classifier')
plt.plot(fpr_SVC, tpr_SVC, label='SVC Classifier')

#plt.plot(fpr, tpr, color='darkorange',lw=lw, label='ROC curve')
plt.plot([0, 1], [0, 1], color='red', lw=lw, label='random', alpha=.8)
plt.xlim([0,1])
plt.ylim([0,1])
plt.xticks(np.arange(0,1.1,0.1))
plt.yticks(np.arange(0,1.1,0.1))

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show();

execution_time = time.time() - start
print('Execution time', time.strftime("%H:%M:%S", time.gmtime(execution_time)))
# Out:
# AUC Logistic regression: 0.5932844270637931
# AUC Tuned Logistic regression: 0.625212423185229
# AUC Decision Tree: 0.5154955968239208
# AUC Tuned Decision Tree: 0.6029576054344599
# AUC Randomforest: 0.5548604997251713
# AUC Tuned Randomforest: 0.5912761629751471
# AUC Bagged Tree Classifier: 0.5815043078532032
# AUC Balanced Bagged Tree Classifier: 0.6290473099602911
# AUC ADABoost: 0.6236668048313897
# AUC Tuned ADABoost: 0.6244519687324723
# AUC Gradient Boosting: 0.6297692403595797
# AUC XGBoost: 0.6291706821562396
# AUC Tuned XGBoost: 0.6281750433283572
# AUC SVC: 0.609032488772465
# Execution time 00:00:00

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # Finalize Save Model for Later Use

# %% [markdown]
# ### Now that we have selected our best model, let us run and save the model for later use.

# %%
start = time.time()

X, y = load_data('final_data.csv')                                      # load data
X_train, X_test, y_train, y_test  = split_train_test(X, y)              # split data

XGB = XGBClassifier().fit(X_train, y_train)                              # define/fit model

XGB_probs = XGB.predict_proba(X_test)[:, 1]              # predict probabilities for the positive outcome only
y_pred = XGB.predict(X_test)                                             # predict


#  Once our model is validated and we're ok with the test predictions let's go ahead and save it.

with open('XBGmodel_pickle', 'wb') as f:
    pickle.dump(model,f)   
    
# I've got my predictions now


#Let's examine the accuracy of the predictions - the predictions compared to the true values

y_hats = XGB.predict(X_test)     

y_test['preds'] = y_hats

df_predictions = pd.merge(df,y_test[['preds']],how = 'left',left_index = True, right_index = True)
df_predictions[df_predictions['readmitted_x']==1]
    
exec_time()
# Out:
# Execution time 00:00:05

# %%
#To open the model for later use do
with open('XBGmodel_pickle', 'rb') as f:
    xgb_mp= pickle.load(f)

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# # iNterpreting the Data

# %% [markdown]
# 1. From the above we can see that the accuracy levels of XGBoost Classifier after tuning and GradientBoost Classifier is among the best, about 63%.
# 2. The accuracy of all the models are similar and ranges between 62-64%, with the exception of KNN which is has the worst performance in distinguishing between patients with readmissions and no readmissions.  Further, applying more pre-processing techniques might help. The dataset needs more data cleaning and data fitting to achieve a higher degree of accuracy.
# 3. Looking at the false positives and the recall value which is approx 60% in Random forest, it gives us better results than the rest.
# 4. The above visual helps us in seeing the accuracy and the ROC curves further helps us decide the performance of different models.

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]

# %% [markdown]
# ## Future Work

# %% [markdown]
# While the results from our predictive model (AUC=.64: Accuracy=91.47%) is encouraging and a good baseline for further improving our model we learned that our classifiers may have high accuracies, it could be misleading and may need further exploration and consideration of other sampling techniques, algorithms, metrics like Precision, Recall or F1-score that work well with unbalanced data.
#
# + Implement dashboard of Inpatient encounters and their predicted readmission risk scores and rankings.
# + Measure and monitor reduction in readmission rates
# + Explore further model improvements/tuning resampling techniques to improve the accuracy of the predictive model
# + Experiment on further Feature selection and elimination
# + Take best models and Ensemble
# + Use alternative metrics for evaluation & thresholding
# + Explore optimal tuning parameters to improve accuracy of imbalanced classes
# + Use metrics that are robust against unbalanced datasets

# %% [markdown]
# [<a href="#Module-5-Final-Project">Jump back to Table of Contents</a>]
